# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='qid')

# %%
pd.set_option('display.max_columns', 88)
pd.set_option('display.max_rows', 88)

# %%
df.columns = [x.lower() for x in df.columns]
df.head(3)
# Out:
#                                                    mainbranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
#
#                                                    employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
#
#                        country us_state uk_country  \
# ResponseId
# 1                     Slovakia      NaN        NaN
# 2                  Netherlands      NaN        NaN
# 3           Russian Federation      NaN        NaN
#
#                                                       edlevel     age1stcode  \
# ResponseId
# 1           Secondary school (e.g. American high school, G...  18 - 24 years
# ...

# %%
schema_df.head(3)
# Out:
#           qname                                           question  \
# qid
# QID16        S0  <div><span style="font-size:19px;"><strong>Hel...
# QID12  MetaInfo                                  Browser Meta Info
# QID1         S1  <span style="font-size:22px; font-family: aria...
#
#        force_resp  type selector
# qid
# QID16       False    DB       TB
# QID12       False  Meta  Browser
# QID1        False    DB       TB

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['NEWSOSites']
# Out:
# ResponseId
# 1                                           Stack Overflow
# 2                                           Stack Overflow
# 3                            Stack Overflow;Stack Exchange
# 4                                           Stack Overflow
# 5                            Stack Overflow;Stack Exchange
#                                ...
# 83435                        Stack Overflow;Stack Exchange
# 83436                        Stack Overflow;Stack Exchange
# 83437                        Stack Overflow;Stack Exchange
# 83438                                       Stack Overflow
# 83439    Stack Overflow;Stack Exchange;Stack Overflow f...
# Name: NEWSOSites, Length: 83439, dtype: object

# %%
df.loc[128:133, 'LanguageWantToWorkWith':'NEWSOSites']
# Out:
#                                        LanguageWantToWorkWith  \
# ResponseId
# 128                                                    C;Dart
# 129                           HTML/CSS;Java;JavaScript;Python
# 130                C#;F#;HTML/CSS;PowerShell;R;SQL;TypeScript
# 131         Bash/Shell;C;C++;Go;HTML/CSS;Java;JavaScript;P...
# 132                       C#;Objective-C;PowerShell;SQL;Swift
# 133                                                       NaN
#
#                                      DatabaseHaveWorkedWith  \
# ResponseId
# 128                                                Firebase
# 129                                    Microsoft SQL Server
# 130         Elasticsearch;Microsoft SQL Server;MySQL;SQLite
# 131                              Elasticsearch;MySQL;SQLite
# 132                                                     NaN
# 133                                                     NaN
#
#                               DatabaseWantToWorkWith PlatformHaveWorkedWith  \
# ...
